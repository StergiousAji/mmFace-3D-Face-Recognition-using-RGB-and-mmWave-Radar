# %%
import pandas as pd

roster = pd.read_html("https://basketball.realgm.com/nba/players")
roster[12]
# Out:
#         #            Player Pos    HT   WT  Age          Current Team  YOS  \
# 0     5.0  Precious Achiuwa  SF   6-8  225   24       Toronto Raptors    3
# 1     4.0      Steven Adams   C  6-11  265   30     Memphis Grizzlies   10
# 2    13.0       Bam Adebayo   C   6-9  255   26            Miami Heat    6
# 3    30.0      Ochai Agbaji  SF   6-5  215   23             Utah Jazz    1
# 4     7.0      Santi Aldama   C   7-0  215   22     Memphis Grizzlies    2
# ..    ...               ...  ..   ...  ...  ...                   ...  ...
# 584  21.0    Thaddeus Young   F   6-8  235   35       Toronto Raptors   16
# 585  11.0        Trae Young  PG   6-1  164   25         Atlanta Hawks    5
# 586  77.0    Omer Yurtseven   C  6-11  275   25             Utah Jazz    3
# 587  40.0       Cody Zeller   F  6-11  240   31  New Orleans Pelicans   10
# 588  40.0       Ivica Zubac   C   7-0  240   26  Los Angeles Clippers    7
#
#              Pre-Draft Team               Draft Status  \
# ...
