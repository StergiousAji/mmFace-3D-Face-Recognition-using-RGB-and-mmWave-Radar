# %%
import pandas as pd

roster = pd.read_html("https://basketball.realgm.com/nba/players")[0]
roster = roster.sort_values("Player")
roster = roster.head(50)
roster
# Out:
#         #              Player Pos    HT   WT  Age            Current Team  \
# 169  20.0          A.J. Green  PG   6-4  190   24         Milwaukee Bucks
# 175  14.0   A.J. Griffin, Jr.  SG   6-6  220   20           Atlanta Hawks
# 265   9.0         A.J. Lawson   F   6-6  179   23        Dallas Mavericks
# 165  50.0        Aaron Gordon   F   6-8  235   28          Denver Nuggets
# 203   0.0       Aaron Holiday  PG   6-0  185   27         Houston Rockets
# 344  23.0       Aaron Nesmith   F   6-6  215   24          Indiana Pacers
# 505  21.0       Aaron Wiggins   F   6-5  190   24   Oklahoma City Thunder
# 414  21.0        Adama Sanogo  PF   6-9  245   22           Chicago Bulls
# 418  25.0   Admiral Schofield  SF   6-5  241   26           Orlando Magic
# 209  42.0          Al Horford  FC   6-9  240   37          Boston Celtics
# 75   14.0          Alec Burks  SG   6-5  214   32         Detroit Pistons
# 372  17.0  Aleksej Pokusevski   C   7-0  210   21   Oklahoma City Thunder
# 85    6.0         Alex Caruso   G   6-5  186   29           Chicago Bulls
# 146  17.0          Alex Fudge   F   6-8  200   22      Los Angeles Lakers
# 269  25.0            Alex Len   C   7-0  250   30        Sacramento Kings
# 422  28.0      Alperen Sengun   C  6-11  243   21         Houston Rockets
# 20   10.0        Amari Bailey   G   6-3  185   20       Charlotte Hornets
# 458   1.0       Amen Thompson   G   6-7  200   20         Houston Rockets
# 97    7.0         Amir Coffey  SF   6-7  210   26    Los Angeles Clippers
# 125   3.0      Andre Drummond   C  6-11  279   30           Chicago Bulls
# 226  44.0  Andre Jackson, Jr.   G   6-6  209   21         Milwaukee Bucks
# 343   2.0     Andrew Nembhard  PG   6-4  191   23          Indiana Pacers
# 506  22.0      Andrew Wiggins   F   6-7  197   28   Golden State Warriors
# 431   1.0     Anfernee Simons  SG   6-3  181   24  Portland Trail Blazers
# 45    0.0       Anthony Black   G   6-7  200   19           Orlando Magic
# 111   3.0       Anthony Davis  PF  6-10  253   30      Los Angeles Lakers
# 131   5.0     Anthony Edwards  SF   6-4  225   22  Minnesota Timberwolves
# 160  16.0        Anthony Gill  PF   6-8  230   31      Washington Wizards
# 61   13.0       Armoni Brooks  SG   6-3  195   25           Brooklyn Nets
# 459   9.0      Ausar Thompson   G   6-6  205   20         Detroit Pistons
# 391  15.0       Austin Reaves  PG   6-5  197   25      Los Angeles Lakers
# 124  12.0         Ayo Dosunmu  PG   6-5  200   23           Chicago Bulls
# 470  20.0     Azuolas Tubelis   F  6-10  245   22     Philadelphia Sixers
# 52    4.0    B.J. Boston, Jr.  SG   6-6  188   21    Los Angeles Clippers
# 2    13.0         Bam Adebayo   C   6-9  255   26              Miami Heat
# 428  26.0        Ben Sheppard   G   6-6  190   22          Indiana Pacers
# 430  10.0         Ben Simmons  PF  6-10  240   27           Brooklyn Nets
# 299   0.0  Bennedict Mathurin  GF   6-5  210   21          Indiana Pacers
# 103   0.0     Bilal Coulibaly  GF   6-8  195   19      Washington Wizards
# 498  14.0        Blake Wesley  SG   6-3  185   20       San Antonio Spurs
# 292  51.0    Boban Marjanovic   C   7-4  290   35         Houston Rockets
# 377   1.0        Bobby Portis  PF  6-10  250   28         Milwaukee Bucks
# 47   13.0   Bogdan Bogdanovic  SG   6-5  225   31           Atlanta Hawks
# 48   44.0    Bojan Bogdanovic   F   6-7  226   34         Detroit Pistons
# 49   11.0             Bol Bol   C   7-3  220   23            Phoenix Suns
# 218   5.0        Bones Hyland   G   6-2  169   23    Los Angeles Clippers
# 36    3.0        Bradley Beal  SG   6-4  207   30            Phoenix Suns
# 370   2.0  Brandin Podziemski   G   6-4  205   20   Golden State Warriors
# 93   15.0      Brandon Clarke  PF   6-8  215   27       Memphis Grizzlies
# 220  14.0      Brandon Ingram  SF   6-8  190   26    New Orleans Pelicans
#
#      YOS                       Pre-Draft Team               Draft Status  \
# 169    1                        Northern Iowa  2022 NBA Draft, Undrafted
# 175    1                                 Duke         2022 Rnd 1 Pick 16
# 265    1                       South Carolina  2021 NBA Draft, Undrafted
# 165    9                              Arizona          2014 Rnd 1 Pick 4
# 203    5                                 UCLA         2018 Rnd 1 Pick 23
# 344    3                           Vanderbilt         2020 Rnd 1 Pick 14
# 505    2                             Maryland         2021 Rnd 2 Pick 25
# 414    0                                UConn  2023 NBA Draft, Undrafted
# 418    3                            Tennessee         2019 Rnd 2 Pick 12
# 209   16                              Florida          2007 Rnd 1 Pick 3
# 75    12                             Colorado         2011 Rnd 1 Pick 12
# 372    3              Olympiacos U18 (Greece)         2020 Rnd 1 Pick 17
# 85     6                            Texas A&M  2016 NBA Draft, Undrafted
# 146    0                              Florida  2023 NBA Draft, Undrafted
# 269   10                             Maryland          2013 Rnd 1 Pick 5
# 422    2            Besiktas Icrypex (Turkey)         2021 Rnd 1 Pick 16
# 20     0                                 UCLA         2023 Rnd 2 Pick 11
# 458    0             Overtime Elite (Georgia)          2023 Rnd 1 Pick 4
# 97     4                            Minnesota  2019 NBA Draft, Undrafted
# 125   11                                UConn          2012 Rnd 1 Pick 9
# 226    0                                UConn          2023 Rnd 2 Pick 6
# 343    1                              Gonzaga          2022 Rnd 2 Pick 1
# 506    9                               Kansas          2014 Rnd 1 Pick 1
# 431    5                IMG Academy (Florida)         2018 Rnd 1 Pick 24
# 45     0                             Arkansas          2023 Rnd 1 Pick 6
# 111   11                             Kentucky          2012 Rnd 1 Pick 1
# 131    3                              Georgia          2020 Rnd 1 Pick 1
# 160    3                             Virginia  2016 NBA Draft, Undrafted
# 61     2                              Houston  2019 NBA Draft, Undrafted
# 459    0             Overtime Elite (Georgia)          2023 Rnd 1 Pick 5
# 391    2                             Oklahoma  2021 NBA Draft, Undrafted
# 124    2                             Illinois          2021 Rnd 2 Pick 8
# 470    0                              Arizona  2023 NBA Draft, Undrafted
# 52     2                             Kentucky         2021 Rnd 2 Pick 21
# 2      6                             Kentucky         2017 Rnd 1 Pick 14
# 428    0                              Belmont         2023 Rnd 1 Pick 26
# 430    7                                  LSU          2016 Rnd 1 Pick 1
# 299    1                              Arizona          2022 Rnd 1 Pick 6
# 103    0  Espoirs Boulogne-Levallois (France)          2023 Rnd 1 Pick 7
# 498    1                           Notre Dame         2022 Rnd 1 Pick 25
# 292    8          KK Vrsac Swisslion (Serbia)  2010 NBA Draft, Undrafted
# 377    8                             Arkansas         2015 Rnd 1 Pick 22
# 47     6                 KK Partizan (Serbia)         2014 Rnd 1 Pick 27
# 48     9                  KK Cibona (Croatia)          2011 Rnd 2 Pick 1
# 49     4                               Oregon         2019 Rnd 2 Pick 14
# 218    2                                  VCU         2021 Rnd 1 Pick 26
# 36    11                              Florida          2012 Rnd 1 Pick 3
# 370    0                          Santa Clara         2023 Rnd 1 Pick 19
# 93     4                              Gonzaga         2019 Rnd 1 Pick 21
# 220    7                                 Duke          2016 Rnd 1 Pick 2
#
#                           Nationality
# 169                     United States
# 175                     United States
# 265                            Canada
# 165                     United States
# 203                     United States
# 344                     United States
# 505                     United States
# 414                              Mali
# 418                     United States
# 209  Dominican Republic United States
# 75                      United States
# 372                            Serbia
# 85                      United States
# 146                     United States
# 269                           Ukraine
# 422                            Turkey
# 20                      United States
# 458                     United States
# 97                      United States
# 125                     United States
# 226                     United States
# 343                            Canada
# 506                            Canada
# 431                     United States
# 45                      United States
# 111                     United States
# 131                     United States
# 160                     United States
# 61                      United States
# 459                     United States
# 391                     United States
# 124                     United States
# 470                         Lithuania
# 52                      United States
# 2                       United States
# 428                     United States
# 430                         Australia
# 299                      Canada Haiti
# 103                            France
# 498                     United States
# 292                            Serbia
# 377                     United States
# 47                             Serbia
# 48     Bosnia and Herzegovina Croatia
# 49                      United States
# 218                     United States
# 36                      United States
# 370                     United States
# 93                             Canada
# 220                     United States

# %%
import json
import requests
from tqdm import tqdm
import os

BASE_DIR = os.getcwd()
headers ={
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36'
}

def search_image_urls(query, num_pages=3):
    url = "https://google.serper.dev/images"
    payload = json.dumps([{'q': query, 'page': p} for p in range(1, num_pages+1)])

    headers = {
        'X-API-KEY': "9d8c3bae3f68d967afdd8a87e6be0691ba19ef83",
        'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    response = json.loads(response.text)

    image_urls = [img["imageUrl"] for res in response for img in res["images"]]
    
    return image_urls, response


for i in tqdm(range(len(roster))):
    name = roster.iloc[i]['Player']
    player_dir = f'{BASE_DIR}/data/raw/{name}'
    # os.makedirs(player_dir, exist_ok=True)

    query = f'{name} NBA'
    # image_urls, response = search_image_urls(query)
    # for i, url in enumerate(image_urls):
    #     with open(os.path.join(player_dir, f"{i}.png"), "wb") as image_file:
    #         image_file.write(requests.get(url, headers=headers).content)
# Out:
# 100%|██████████| 50/50 [24:46<00:00, 29.72s/it]

# %%
import insightface
from insightface.app.common import Face
from insightface.model_zoo import model_zoo
import cv2
import os

BASE_DIR = os.getcwd()

det_model_path = os.path.join(BASE_DIR, "models", "buffalo_l", "det_10g.onnx")
rec_model_path = os.path.join(BASE_DIR, "models", "buffalo_l", "w600k_r50.onnx")

det_model = model_zoo.get_model(det_model_path)
rec_model = model_zoo.get_model(rec_model_path)

det_model.prepare(ctx_id=0, input_size=(640, 640), det_thres=0.5)
# Out:
# cuda
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CUDAExecutionProvider': {'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'device_id': '0', 'gpu_external_alloc': '0', 'enable_cuda_graph': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_free': '0', 'gpu_external_empty_cache': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'cudnn_conv_use_max_workspace': '1', 'cudnn_conv1d_pad_to_nc1d': '0', 'tunable_op_enable': '0', 'tunable_op_tuning_enable': '0', 'enable_skip_layer_norm_strict_mode': '0'}, 'CPUExecutionProvider': {}}
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CUDAExecutionProvider': {'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'device_id': '0', 'gpu_external_alloc': '0', 'enable_cuda_graph': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_free': '0', 'gpu_external_empty_cache': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'cudnn_conv_use_max_workspace': '1', 'cudnn_conv1d_pad_to_nc1d': '0', 'tunable_op_enable': '0', 'tunable_op_tuning_enable': '0', 'enable_skip_layer_norm_strict_mode': '0'}, 'CPUExecutionProvider': {}}
# GPU
